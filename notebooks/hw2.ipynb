# %%
# %%capture
# !pip install rectools

# %%
import copy
import pprint

import pandas as pd
import numpy as np

import requests
from tqdm.notebook import tqdm

from rectools import Columns
from rectools.dataset import Interactions, Dataset
from rectools.metrics import (
    Precision,
    Accuracy,
    MAP,
    NDCG,
    Serendipity,
    calc_metrics,
)
from rectools.metrics.novelty import NoveltyMetric
from rectools.models import (
    PopularModel,
    RandomModel
)
from rectools.model_selection import TimeRangeSplitter

# %% [markdown]
# # Load data

# %%
url = 'https://github.com/irsafilo/KION_DATASET/raw/f69775be31fa5779907cf0a92ddedb70037fb5ae/data_original.zip'

# %%
req = requests.get(url, stream=True)

with open('kion.zip', 'wb') as fd:
    total_size_in_bytes = int(req.headers.get('Content-Length', 0))
    progress_bar = tqdm(desc='kion dataset download', total=total_size_in_bytes, unit='iB', unit_scale=True)
    for chunk in req.iter_content(chunk_size=2 ** 20):
        progress_bar.update(len(chunk))
        fd.write(chunk)
# Out:
# kion dataset download:   0%|          | 0.00/78.8M [00:00<?, ?iB/s]

# %%
import zipfile as zf

files = zf.ZipFile('kion.zip','r')
files.extractall()
files.close()

# %%
#Load data

# %%
interactions = pd.read_csv('data_original/interactions.csv', parse_dates=["last_watch_dt"])

interactions.rename(
    columns={
        'last_watch_dt': Columns.Datetime,
        'total_dur': Columns.Weight
    }, 
    inplace=True)

# %%
train_interactions = Interactions(interactions)

# %%
users = pd.read_csv('data_original/users.csv')
items = pd.read_csv('data_original/items.csv')

# %%
def headtail(df):
    return pd.concat([df.head(), df.tail()])

headtail(interactions)
# Out:
#          user_id  item_id   datetime  weight  watched_pct
# 0         176549     9506 2021-05-11    4250         72.0
# 1         699317     1659 2021-05-29    8317        100.0
# 2         656683     7107 2021-05-09      10          0.0
# 3         864613     7638 2021-07-05   14483        100.0
# 4         964868     9506 2021-04-30    6725        100.0
# 5476246   648596    12225 2021-08-13      76          0.0
# 5476247   546862     9673 2021-04-13    2308         49.0
# 5476248   697262    15297 2021-08-20   18307         63.0
# 5476249   384202    16197 2021-04-19    6203        100.0
# 5476250   319709     4436 2021-08-15    3921         45.0

# %% [markdown]
# # Initialization

# %%
N_SPLITS = 3
K = 10
RANDOM_STATE = 32

# %% [markdown]
# ## Init splitter

# %%
# валидируем на 3 периодах по неделе
n_splits = N_SPLITS

cv = TimeRangeSplitter(
    test_size="7D",
    n_splits=n_splits,
    filter_already_seen=True,
    filter_cold_items=True,
    filter_cold_users=True,
)

# %% [markdown]
# ## Init models

# %%
models = {
    'random_model': RandomModel(random_state=RANDOM_STATE),
    'popular': PopularModel()
}

# %% [markdown]
# ## Init metrics

# %%
# classifier
precision_1 = Precision(k=1)
precision_5 = Precision(k=5)
precision = Precision(k=K)
accuracy_1 = Accuracy(k=1)
accuracy_5 = Accuracy(k=5)
accuracy = Accuracy(k=K)

#ranking
map_k = MAP(k=K, divide_by_k=True)
ndcg = NDCG(k=K, log_base=3)

#beyond accuracy
serendipity = Serendipity(k=K)
novelty = NoveltyMetric(k=K)

# %%
metrics = {
    "precision@1": precision_1,
    "accuracy@1": accuracy_1,
    "precision@5": precision_5,
    "accuracy@5": accuracy_5,
    "precision@k": precision,
    "accuracy@k": accuracy,
    "map": map_k,
    "ndcg": ndcg,
    "serendipity": serendipity,
    "novelty": novelty,
}

# %% [markdown]
# # Расчёт метрик

# %%
class RecoService:
    def __init__(self, 
                 interactions: pd.DataFrame,
                 models: dict,
                 metrics: dict,
                 splitter: TimeRangeSplitter,
                 k: int,
                 n_splits: int = N_SPLITS    
                ):
        self.interactions = interactions
        
        self.models = models
        self.metrics = metrics
        
        self.splitter = splitter
        self.n_splits = n_splits
        
        self.k = k
        
        
    def train(self):
        results, last_models = list(), dict()
        
        cv = self.splitter.split(self.interactions)
        
        for train_ids, test_ids, fold_info in tqdm((cv), total=self.n_splits):
            print(f"\n==================== Fold {fold_info['i_split']}")
            print(fold_info)
            
            df_train = self.interactions.df.iloc[train_ids]
            dataset = Dataset.construct(df_train)

            df_test = self.interactions.df.iloc[test_ids][Columns.UserItem]
            test_users = np.unique(df_test[Columns.User])

            # Catalog is set of items that we recommend.
            # Sometimes we recommend not all items from train.
            catalog = df_train[Columns.Item].unique()

            for model_name, model in self.models.items():
                model = copy.deepcopy(model)
                model.fit(dataset)
                
                recos = model.recommend(
                    users=test_users,
                    dataset=dataset,
                    k=self.k,
                    filter_viewed=True,
                )
                
                metric_values = calc_metrics(
                    self.metrics,
                    reco=recos,
                    interactions=df_test,
                    prev_interactions=df_train,
                    catalog=catalog,
                )
                res = {"fold": fold_info["i_split"], "model": model_name}
                res.update(metric_values)
                results.append(res)
                last_models[model_name] = model
        
        pivot_results = pd.DataFrame(results).drop(columns="fold").groupby(["model"], sort=False).agg("mean")
        
        return {
                'results': pivot_results,
                'models': last_models
        }

# %%
reco = RecoService(
    interactions = train_interactions,
    models = models,
    metrics = metrics,
    splitter = cv,
    k = K
)

# %%
# %%time

output = reco.train()
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# ==================== Fold 0
# {'i_split': 0, 'start': Timestamp('2021-08-02 00:00:00'), 'end': Timestamp('2021-08-09 00:00:00')}
#
# ==================== Fold 1
# {'i_split': 1, 'start': Timestamp('2021-08-09 00:00:00'), 'end': Timestamp('2021-08-16 00:00:00')}
#
# ==================== Fold 2
# {'i_split': 2, 'start': Timestamp('2021-08-16 00:00:00'), 'end': Timestamp('2021-08-23 00:00:00')}
# CPU times: user 57.9 s, sys: 2.08 s, total: 60 s
# Wall time: 1min

# %%
(
    output['results'].style
    .highlight_min(color='lightcoral', axis=0)
    .highlight_max(color='lightgreen', axis=0)
)
# Out:
# <style type="text/css">
# #T_2e2ba_row0_col0, #T_2e2ba_row0_col1, #T_2e2ba_row0_col2, #T_2e2ba_row0_col3, #T_2e2ba_row0_col4, #T_2e2ba_row0_col5, #T_2e2ba_row0_col6, #T_2e2ba_row0_col7, #T_2e2ba_row1_col8, #T_2e2ba_row1_col9 {
#   background-color: lightcoral;
# }
# #T_2e2ba_row0_col8, #T_2e2ba_row0_col9, #T_2e2ba_row1_col0, #T_2e2ba_row1_col1, #T_2e2ba_row1_col2, #T_2e2ba_row1_col3, #T_2e2ba_row1_col4, #T_2e2ba_row1_col5, #T_2e2ba_row1_col6, #T_2e2ba_row1_col7 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_2e2ba">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e2ba_level0_col0" class="col_heading level0 col0" >precision@1</th>
#       <th id="T_2e2ba_level0_col1" class="col_heading level0 col1" >accuracy@1</th>
#       <th id="T_2e2ba_level0_col2" class="col_heading level0 col2" >precision@5</th>
#       <th id="T_2e2ba_level0_col3" class="col_heading level0 col3" >accuracy@5</th>
#       <th id="T_2e2ba_level0_col4" class="col_heading level0 col4" >precision@k</th>
#       <th id="T_2e2ba_level0_col5" class="col_heading level0 col5" >accuracy@k</th>
#       <th id="T_2e2ba_level0_col6" class="col_heading level0 col6" >ndcg</th>
#       <th id="T_2e2ba_level0_col7" class="col_heading level0 col7" >map</th>
#       <th id="T_2e2ba_level0_col8" class="col_heading level0 col8" >novelty</th>
#       <th id="T_2e2ba_level0_col9" class="col_heading level0 col9" >serendipity</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e2ba_level0_row0" class="row_heading level0 row0" >random_model</th>
#       <td id="T_2e2ba_row0_col0" class="data row0 col0" >0.000221</td>
#       <td id="T_2e2ba_row0_col1" class="data row0 col1" >0.999760</td>
#       <td id="T_2e2ba_row0_col2" class="data row0 col2" >0.000202</td>
#       <td id="T_2e2ba_row0_col3" class="data row0 col3" >0.999500</td>
#       <td id="T_2e2ba_row0_col4" class="data row0 col4" >0.000193</td>
#       <td id="T_2e2ba_row0_col5" class="data row0 col5" >0.999176</td>
#       <td id="T_2e2ba_row0_col6" class="data row0 col6" >0.000200</td>
#       <td id="T_2e2ba_row0_col7" class="data row0 col7" >0.000060</td>
#       <td id="T_2e2ba_row0_col8" class="data row0 col8" >15.613009</td>
#       <td id="T_2e2ba_row0_col9" class="data row0 col9" >0.000007</td>
#     </tr>
#     <tr>
#       <th id="T_2e2ba_level0_row1" class="row_heading level0 row1" >popular</th>
#       <td id="T_2e2ba_row1_col0" class="data row1 col0" >0.076432</td>
#       <td id="T_2e2ba_row1_col1" class="data row1 col1" >0.999770</td>
#       <td id="T_2e2ba_row1_col2" class="data row1 col2" >0.052402</td>
#       <td id="T_2e2ba_row1_col3" class="data row1 col3" >0.999534</td>
#       <td id="T_2e2ba_row1_col4" class="data row1 col4" >0.033903</td>
#       <td id="T_2e2ba_row1_col5" class="data row1 col5" >0.999220</td>
#       <td id="T_2e2ba_row1_col6" class="data row1 col6" >0.043084</td>
#       <td id="T_2e2ba_row1_col7" class="data row1 col7" >0.016591</td>
#       <td id="T_2e2ba_row1_col8" class="data row1 col8" >3.713390</td>
#       <td id="T_2e2ba_row1_col9" class="data row1 col9" >0.000002</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Визуальный анализ

# %%
item_interactions = interactions.df.groupby('item_id')['user_id'].count().to_frame().rename(columns={'user_id': 'count_interactions'}).reset_index()
items = items.merge(item_interactions, on='item_id', how='left')
items['count_interactions'] = items['count_interactions'].fillna(0)

# %%
class VizualizeModel:
    def __init__(
        self,
        model,
        dataset,
        item_data: pd.DataFrame,
        k: int = K,
        item_columns: list = ['item_id', 'content_type', 'title', 'genres', 'count_interactions']
    ):
        self.model = model
        self.k = k
        
        self.interactions = dataset
        self.dataset = Dataset.construct(dataset)
        self.item_data = item_data[item_columns]
    
    def show_recos(self, user_ids: list):
        recos = self.model.recommend(
                    users=user_ids,
                    dataset=self.dataset,
                    k=self.k,
                    filter_viewed=True,
                )
        
        for user in user_ids:
            print(f"\n==================== User {user}")
            watched_ids = self.interactions[self.interactions['user_id']==user]['item_id'].to_frame()
            reco_ids = recos[recos['user_id']==user]['item_id'].to_frame()
            
            history = watched_ids.merge(self.item_data, on='item_id', how='left')
            recommended = reco_ids.merge(self.item_data, on='item_id', how='left')
            
            print('----------History----------')
            display(history)
            
            print('----------Recos----------')
            display(recommended)
            
            print()

# %%
dataset = Dataset.construct(interactions)

model = PopularModel()
model.fit(dataset)

# %%
vizualizer = VizualizeModel(model=model, dataset=interactions, item_data=items)

# %%
vizualizer.show_recos([666262, 672861, 955527])
# Out:
# ==================== User 666262
# ----------History----------
#    item_id content_type              title
# 0     7957         film   Последний викинг  \
# 1     4785         film  Робин Гуд: Начало
# 2    12981         film            Томирис
#
#                                   genres  count_interactions
# 0     боевики, историческое, приключения               746.0
# 1         боевики, триллеры, приключения               485.0
# 2  боевики, драмы, историческое, военные             10370.0
# ----------Recos----------
#    item_id content_type                         title
# 0    10440       series                   Хрустальный  \
# 1    15297       series               Клиника счастья
# 2     9728         film             Гнев человеческий
# 3    13865         film                      Девятаев
# 4     4151       series        Секреты семейной жизни
# 5     3734         film  Прабабушка легкого поведения
# 6     2657       series                    Подслушано
# 7     4880       series                         Афера
# 8      142         film                          Маша
# 9     6809         film                         Дуров
#
#                         genres  count_interactions
# 0          триллеры, детективы            202457.0
# 1             драмы, мелодрамы            193123.0
# 2            боевики, триллеры            132865.0
# 3  драмы, военные, приключения            122119.0
# 4                      комедии             91167.0
# 5                      комедии             74803.0
# 6              драмы, триллеры             68581.0
# 7                      комедии             55043.0
# 8              драмы, триллеры             45367.0
# 9               документальное             40372.0
# ==================== User 672861
# ----------History----------
#    item_id content_type                 title                       genres
# 0     6870         film  Красавица и чудовище  драмы, фэнтези, музыкальные  \
# 1     8662         film           Он – дракон                      фэнтези
#
#    count_interactions
# 0              1083.0
# 1               643.0
# ----------Recos----------
#    item_id content_type                         title
# 0    10440       series                   Хрустальный  \
# 1    15297       series               Клиника счастья
# 2     9728         film             Гнев человеческий
# 3    13865         film                      Девятаев
# 4     4151       series        Секреты семейной жизни
# 5     3734         film  Прабабушка легкого поведения
# 6     2657       series                    Подслушано
# 7     4880       series                         Афера
# 8      142         film                          Маша
# 9     6809         film                         Дуров
#
#                         genres  count_interactions
# 0          триллеры, детективы            202457.0
# 1             драмы, мелодрамы            193123.0
# 2            боевики, триллеры            132865.0
# 3  драмы, военные, приключения            122119.0
# 4                      комедии             91167.0
# 5                      комедии             74803.0
# 6              драмы, триллеры             68581.0
# 7                      комедии             55043.0
# 8              драмы, триллеры             45367.0
# 9               документальное             40372.0
# ==================== User 955527
# ----------History----------
#    item_id content_type                           title
# 0     1183         film  Стань легендой! Бигфут Младший  \
# 1    13371         film          Пеле: Рождение легенды
# 2     4725         film            Лобановский навсегда
# 3     1238         film                  Диего Марадона
#
#                                       genres  count_interactions
# 0  мультфильм, фэнтези, приключения, комедии              1587.0
# 1                    драмы, спорт, биография               945.0
# 2           спорт, биография, документальное               683.0
# 3           спорт, биография, документальное               691.0
# ----------Recos----------
#    item_id content_type                         title
# 0    10440       series                   Хрустальный  \
# 1    15297       series               Клиника счастья
# 2     9728         film             Гнев человеческий
# 3    13865         film                      Девятаев
# 4     4151       series        Секреты семейной жизни
# 5     3734         film  Прабабушка легкого поведения
# 6     2657       series                    Подслушано
# 7     4880       series                         Афера
# 8      142         film                          Маша
# 9     6809         film                         Дуров
#
#                         genres  count_interactions
# 0          триллеры, детективы            202457.0
# 1             драмы, мелодрамы            193123.0
# 2            боевики, триллеры            132865.0
# 3  драмы, военные, приключения            122119.0
# 4                      комедии             91167.0
# 5                      комедии             74803.0
# 6              драмы, триллеры             68581.0
# 7                      комедии             55043.0
# 8              драмы, триллеры             45367.0
# 9               документальное             40372.0

# %%
dataset = Dataset.construct(interactions)
random_model = RandomModel(random_state=RANDOM_STATE)
random_model.fit(dataset)

# %%
vizualizer = VizualizeModel(model=random_model, dataset=interactions, item_data=items)

# %%
vizualizer.show_recos([666262, 672861, 955527])
# Out:
# ==================== User 666262
# ----------History----------
#    item_id content_type              title
# 0     7957         film   Последний викинг  \
# 1     4785         film  Робин Гуд: Начало
# 2    12981         film            Томирис
#
#                                   genres  count_interactions
# 0     боевики, историческое, приключения               746.0
# 1         боевики, триллеры, приключения               485.0
# 2  боевики, драмы, историческое, военные             10370.0
# ----------Recos----------
#    item_id content_type                                         title
# 0    10101       series                           Возвращение Будулая  \
